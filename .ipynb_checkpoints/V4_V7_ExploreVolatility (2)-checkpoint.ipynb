# %% [markdown]
# # Volatility Data Analysis
#
# ### February 13 2018
#
# #### John Ngo

# %%
# import packages and function

import numpy as np
import pandas as pd
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# import data and display the first few rows

vix = pd.read_csv('vix.csv')

vix.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  1990-01-02  17.240000  17.240000  17.240000  17.240000  17.240000       0
# 1  1990-01-03  18.190001  18.190001  18.190001  18.190001  18.190001       0
# 2  1990-01-04  19.219999  19.219999  19.219999  19.219999  19.219999       0
# 3  1990-01-05  20.110001  20.110001  20.110001  20.110001  20.110001       0
# 4  1990-01-08  20.260000  20.260000  20.260000  20.260000  20.260000       0

# %%
v = pd.read_csv('v.csv')

print(v.shape)
v.head()

# vp = v['Close'].values
# plt.plot(np.arange(vp[:300].shape[0]), vp[:300])
# Out:
# (3185, 10)
#    Trade Date   Open   High    Low  Close  Settle  Change  Total Volume  \
# 0  2018-02-12  26.50  28.37  24.75  25.82  25.825   -1.35      105688.0
# 1  2018-02-09  27.95  32.90  26.15  27.15  27.175   -0.92      187082.0
# 2  2018-02-08  23.10  29.90  22.25  28.05  28.100    4.68      217066.0
# 3  2018-02-07  23.90  24.47  19.50  23.45  23.425   -0.45      214118.0
# 4  2018-02-06  31.75  33.25  20.00  23.90  23.875   -9.35      511008.0
#
#       EFP  Prev. Day Open Interest
# 0   120.0                  77788.0
# 1    13.0                  93755.0
# 2  6389.0                 106139.0
# 3  3510.0                 126815.0
# 4  4670.0                 172816.0

# %%
vv = pd.read_csv('vv.csv')

print(vv.shape)
vv.head()

# vvp = vv['Close'].values
# plt.plot(np.arange(vvp[-300:].shape[0]), vvp[-300:])

# vv.iloc[-140, 0]
# Out:
# (3079, 10)
#    Trade Date   Open   High    Low  Close  Settle  Change  Total Volume  \
# 0  2018-02-12  20.30  21.20  19.75  19.85  19.825   -0.60      183266.0
# 1  2018-02-09  21.60  23.44  20.34  20.40  20.425   -1.22      231284.0
# 2  2018-02-08  19.70  23.39  18.75  21.60  21.650    1.78      270960.0
# 3  2018-02-07  20.45  20.90  17.80  19.90  19.875   -1.15      283310.0
# 4  2018-02-06  27.40  28.00  18.10  21.00  21.025   -6.95      675499.0
#
#        EFP  Prev. Day Open Interest
# 0   5507.0                 235693.0
# 1    917.0                 231520.0
# 2   2598.0                 224701.0
# 3      0.0                 218471.0
# 4  10748.0                 249519.0

# %%
spy = pd.read_csv('spy.csv')

print(spy.shape)
spy.head()
#print(spy.iloc[0, :])
#print(spy.iloc[-1, :])
# Out:
# (6307, 7)
#          Date     Open     High      Low    Close  Adj Close   Volume
# 0  1993-01-29  43.9687  43.9687  43.7500  43.9375  27.466780  1003200
# 1  1993-02-01  43.9687  44.2500  43.9687  44.2500  27.662146   480500
# 2  1993-02-02  44.2187  44.3750  44.1250  44.3437  27.720715   201300
# 3  1993-02-03  44.4062  44.8437  44.3750  44.8125  28.013771   529400
# 4  1993-02-04  44.9687  45.0937  44.4687  45.0000  28.130983   531500

# %%
uvxy = pd.read_csv('uvxy.csv')

print(uvxy.shape)
uvxy.head()
# Out:
# (1601, 7)
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2011-10-04  48540000.0  48960000.0  41160000.0  41160000.0  41160000.0
# 1  2011-10-05  39492000.0  39780000.0  36276000.0  36276000.0  36276000.0
# 2  2011-10-06  36228000.0  37560000.0  34800000.0  34800000.0  34800000.0
# 3  2011-10-07  34116000.0  37152000.0  33696000.0  35304000.0  35304000.0
# 4  2011-10-10  33096000.0  33120000.0  31188000.0  31188000.0  31188000.0
#
#    Volume
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
vxx = pd.read_csv('vxx.csv')

vxx.head()

# vxxp = vxx['Close'].values
# plt.plot(np.arange(vxxp[-500:].shape[0]), vxxp[-500:])
# Out:
#          Date           Open           High            Low          Close  \
# 0  2009-01-30  102512.640625  107560.960938  102144.000000  107089.921875
# 1  2009-02-02  110694.398438  110694.398438  106434.562500  106752.000000
# 2  2009-02-03  106639.359375  106639.359375  101693.437500  101754.882813
# 3  2009-02-04  100608.000000  102799.359375   99328.000000  102133.757813
# 4  2009-02-05  104038.398438  106280.960938  100505.601563  101509.117188
#
#        Adj Close Volume
# 0  107089.921875    200
# 1  106752.000000    300
# 2  101754.882813    100
# 3  102133.757813    100
# 4  101509.117188    200

# %%
v4 = pd.read_csv('v4.csv')

v4.head()
# Out:
#    Trade Date   Open   High    Low  Close  Settle  Change  Total Volume  EFP  \
# 0  2018-02-15  17.85  17.98  17.25  17.32  17.325   -0.50       26165.0  0.0
# 1  2018-02-14  18.58  19.30  17.80  17.85  17.825   -0.78       30686.0  0.0
# 2  2018-02-13  18.45  19.16  18.40  18.60  18.600    0.12       16934.0  0.0
# 3  2018-02-12  18.40  19.05  18.10  18.50  18.475   -0.05       23957.0  0.0
# 4  2018-02-09  19.70  20.95  18.40  18.40  18.525   -1.32       32989.0  0.0
#
#    Prev. Day Open Interest
# 0                  36472.0
# 1                  37935.0
# 2                  36270.0
# 3                  37455.0
# 4                  38260.0

# %%
v7 = pd.read_csv('v7.csv')

v7.head()
# Out:
#    Trade Date   Open   High    Low  Close  Settle  Change  Total Volume  EFP  \
# 0  2018-02-15  17.85  17.85  17.28  17.35  17.375   -0.35        4400.0  0.0
# 1  2018-02-14  18.15  18.60  17.63  17.75  17.725   -0.40        5477.0  0.0
# 2  2018-02-13  17.94  18.50  17.90  18.10  18.125    0.20        3676.0  0.0
# 3  2018-02-12  17.67  18.20  17.45  17.94  17.925    0.22        5925.0  0.0
# 4  2018-02-09  18.75  19.72  17.69  17.69  17.700   -1.05        7674.0  0.0
#
#    Prev. Day Open Interest
# 0                  23206.0
# 1                  23404.0
# 2                  23195.0
# 3                  22693.0
# 4                  22911.0

# %%
#organize dates in order --> need all values on same day to calculate
v_dates = v.loc[:, 'Trade Date'].values
vmin, vmax = np.amin(v_dates), np.amax(v_dates)
vv_dates = vv.loc[:, 'Trade Date'].values
vvmin, vvmax = np.amin(vv_dates), np.amax(vv_dates)
spy_dates = spy.loc[:, 'Date'].values
spymin, spymax = np.amin(spy_dates), np.amax(spy_dates)
vxx_dates = vxx.loc[:, 'Date'].values
vxxmin = np.amin(vxx_dates)
v4_dates = v4.loc[:, 'Trade Date'].values
v4min = np.amin(v4_dates)
v7_dates = v7.loc[:, 'Trade Date'].values
v7min = np.amin(v7_dates)

start_date = np.argmax([vmin, vvmin, spymin, vxxmin, v4min, v7min]) #first date will all values
dates = [v_dates, vv_dates, spy_dates, vxx_dates, v4_dates, v7_dates][start_date]
dates #= np.flip(dates, axis = 0) #ordered dates for comparison
# Out:
# array(['2009-01-30', '2009-02-02', '2009-02-03', ..., '2018-02-09',
#        '2018-02-12', '2018-02-13'], dtype=object)

# %%
#organize values into new array / dataframe
columns = ['Date', 'V', 'VV', 'SPY', 'VXX', 'V4', 'V7', '(VV - V) / VV',  '[((VV-V)/VV) - ((V7-V4)/(V7*3))]', 'Holding',\
           'Held Value', 'Cash', 'Trade Sum', 'Long Term Shares', 'Long Term Value']
                                                

daily_values = np.empty((len(dates), len(columns)), dtype = object)

for i in range(len(dates)):
    if dates[i] not in v['Trade Date'].values:
        #daily_values[i, 0] = np.nan
        continue
    v_close = v.loc[v.loc[:, 'Trade Date'] == dates[i], 'Close'].values[0]
    vv_close = vv.loc[vv.loc[:, 'Trade Date'] == dates[i], 'Close'].values[0]
    spy_close = spy.loc[spy.loc[:, 'Date'] == dates[i], 'Close'].values[0]
    vxx_close = vxx.loc[vxx.loc[:, 'Date'] == dates[i], 'Close'].values[0]
    v4_close = v4.loc[v4.loc[:, 'Trade Date'] == dates[i], 'Close'].values[0]
    v7_close = v7.loc[v7.loc[:, 'Trade Date'] == dates[i], 'Close'].values[0]
    daily_values[i, 0] = dates[i]
    daily_values[i, 1] = float(v_close)
    daily_values[i, 2] = float(vv_close)
    daily_values[i, 3] = float(spy_close)
    daily_values[i, 4] = float(vxx_close)
    daily_values[i, 5] = float(v4_close)
    daily_values[i, 6] = float(v7_close)
    daily_values[i, 7] = float((vv_close - v_close)/vv_close)
    daily_values[i, 8] = daily_values[i, 7] - float(((v7_close - v4_close)/(v7_close * 3)))
    
summary = pd.DataFrame(daily_values, columns = columns, copy = True)
summary.dropna(axis = 0, how = 'all', inplace = True)
summary.reset_index(drop = True, inplace = True)
summary.head()
# Out:
#          Date      V     VV    SPY     VXX     V4     V7 (VV - V) / VV  \
# 0  2009-01-30  44.96  42.21  82.83  107090  38.95  36.96    -0.0651504
# 1  2009-02-02   45.4  42.35  82.58  106752   39.5  37.78    -0.0720189
# 2  2009-02-03  43.05     41  83.74  101755  38.65  37.65         -0.05
# 3  2009-02-04  43.75   41.1  83.33  102134   38.3  37.25    -0.0644769
# 4  2009-02-05   43.2  40.45  84.57  101509     38   37.1    -0.0679852
#
#   [((VV-V)/VV) - ((V7-V4)/(V7*3))] Holding Held Value  Cash Trade Sum  \
# 0                       -0.0472031    None       None  None      None
# 1                       -0.0568433    None       None  None      None
# 2                       -0.0411465    None       None  None      None
# 3                       -0.0550809    None       None  None      None
# 4                       -0.0598989    None       None  None      None
#
#   Long Term Shares Long Term Value
# 0             None            None
# 1             None            None
# 2             None            None
# 3             None            None
# 4             None            None

# %% [markdown]
# Define the initial amount of money invested and the cost per trade.
# Can add additional inputs if needed.
# Dates range from 2009 to 2018

# %%
initial_investment = 1000 #amount of money to invest initially (assumes only 1 influx of money)
trade_cost = 0 #fixed amount, can change to percentage
threshold = 0 #to make decision set at a threshold above or below 0 (VV - V / VV)

# %%
#if ['VV - V / VV'] > 0 , buy SPY. If < 0, sell SPY

def simulate_returnsVV(dataframe, initial_investment, trade_cost, threshold, start_date=None):
    """
    Simulates returns from shorting VXX using existing dataset (fixed dataset based on summary dataframe)
    allows for varying the initial_investment, trade_cost, threshold, and start date (date must be in dataframe)
    Utilizes old formula (VV-V)/VV
    """
    
    if start_date is not None:
        d1 = np.where(dataframe['Date'].values == start_date)[0][0]
        summary = dataframe.iloc[d1:, :].copy()
        summary.reset_index(drop = True, inplace = True)
    else:
        summary = dataframe.copy()
    
    summary = dataframe.copy()
    
    summary.loc[0, 'Holding':] = float(0) #initialize as 0 holdings
    LTshares = (initial_investment - trade_cost) / summary.loc[0, 'SPY']
    summary.loc[0, 'Long Term Shares'] = LTshares
    summary.loc[0, 'Long Term Value'] = initial_investment - trade_cost
    summary.loc[0, 'Cash'] = initial_investment

    def update_row(df, row):
        """
        basic steps that will be repeated to update each row of summary DF
        """
        df.loc[row, 'Held Value'] = df.loc[row, 'Holding']*df.loc[row, 'SPY']
        df.loc[row, 'Long Term Shares'] = LTshares
        df.loc[row, 'Long Term Value'] = df.loc[row, 'Long Term Shares']*df.loc[row, 'SPY']
        df.loc[row, 'Trade Sum'] = df.loc[row, 'Cash'] + df.loc[row, 'Held Value']
        return df

    for i in range(1, summary.shape[0]):
        #print(i)
        if np.absolute(summary.loc[i, '(VV - V) / VV']) <= threshold: #do nothing
            #print('do nothing')
            summary.loc[i, 'Holding'] = summary.loc[i-1, 'Holding']
            summary.loc[i, 'Cash'] = summary.loc[i-1, 'Cash']
            summary = update_row(summary, i)

        elif (summary.loc[i, '(VV - V) / VV'] + threshold > 0) & (summary.loc[i-1, 'Holding'] == 0): #buy
            #print(buy)
            summary.loc[i, 'Holding'] = (summary.loc[i-1, 'Cash'] - trade_cost) / summary.loc[i, 'SPY']
            summary.loc[i, 'Cash'] = 0
            summary = update_row(summary, i)

        elif (summary.loc[i, '(VV - V) / VV'] - threshold < 0) & (summary.loc[i-1, 'Held Value'] != 0): #sell
            #print('sell')
            summary.loc[i, 'Cash'] = summary.loc[i-1, 'Held Value'] - trade_cost
            summary.loc[i, 'Holding'] = 0
            summary.loc[i, 'Held Value'] = 0
            summary = update_row(summary, i)

        else: #also do nothing
            #print('do nothing')
            summary.loc[i, 'Holding'] = summary.loc[i-1, 'Holding']
            summary.loc[i, 'Cash'] = summary.loc[i-1, 'Cash']
            summary = update_row(summary, i)
            
    return summary

# %%
#if -[((VV-V)/VV) - ((V7-V4)/(V7*3))] > 0 , buy SPY. If < 0, sell SPY

def simulate_returnsV47SPY(dataframe, initial_investment, trade_cost, threshold, start_date=None):
    """
    Simulates returns from buying SPY using existing dataset (fixed dataset based on summary dataframe)
    allows for varying the initial_investment, trade_cost, threshold, and start date (date must be in dataframe)
    Utilizes new formula [((VV-V)/VV) - ((V7-V4)/(V7*3))]
    """
    
    if start_date is not None:
        d1 = np.where(dataframe['Date'].values == start_date)[0][0]
        summary = dataframe.iloc[d1:, :].copy()
        summary.reset_index(drop = True, inplace = True)
    else:
        summary = dataframe.copy()
    
    summary = dataframe.copy()
    
    summary.loc[0, 'Holding':] = float(0) #initialize as 0 holdings
    LTshares = (initial_investment - trade_cost) / summary.loc[0, 'SPY']
    summary.loc[0, 'Long Term Shares'] = LTshares
    summary.loc[0, 'Long Term Value'] = initial_investment - trade_cost
    summary.loc[0, 'Cash'] = initial_investment

    def update_row(df, row):
        """
        basic steps that will be repeated to update each row of summary DF
        """
        df.loc[row, 'Held Value'] = df.loc[row, 'Holding']*df.loc[row, 'SPY']
        df.loc[row, 'Long Term Shares'] = LTshares
        df.loc[row, 'Long Term Value'] = df.loc[row, 'Long Term Shares']*df.loc[row, 'SPY']
        df.loc[row, 'Trade Sum'] = df.loc[row, 'Cash'] + df.loc[row, 'Held Value']
        return df

    for i in range(1, summary.shape[0]):
        #print(i)
        if np.absolute(summary.loc[i, '[((VV-V)/VV) - ((V7-V4)/(V7*3))]']) <= threshold: #do nothing
            #print('do nothing')
            summary.loc[i, 'Holding'] = summary.loc[i-1, 'Holding']
            summary.loc[i, 'Cash'] = summary.loc[i-1, 'Cash']
            summary = update_row(summary, i)

        elif (summary.loc[i, '[((VV-V)/VV) - ((V7-V4)/(V7*3))]'] + threshold > 0) & (summary.loc[i-1, 'Holding'] == 0): #buy
            #print(buy)
            summary.loc[i, 'Holding'] = (summary.loc[i-1, 'Cash'] - trade_cost) / summary.loc[i, 'SPY']
            summary.loc[i, 'Cash'] = 0
            summary = update_row(summary, i)

        elif (summary.loc[i, '[((VV-V)/VV) - ((V7-V4)/(V7*3))]'] - threshold < 0) & (summary.loc[i-1, 'Held Value'] != 0): #sell
            #print('sell')
            summary.loc[i, 'Cash'] = summary.loc[i-1, 'Held Value'] - trade_cost
            summary.loc[i, 'Holding'] = 0
            summary.loc[i, 'Held Value'] = 0
            summary = update_row(summary, i)

        else: #also do nothing
            #print('do nothing')
            summary.loc[i, 'Holding'] = summary.loc[i-1, 'Holding']
            summary.loc[i, 'Cash'] = summary.loc[i-1, 'Cash']
            summary = update_row(summary, i)
            
    return summary

# %%
# if -[((VV-V)/VV) - ((V7-V4)/(V7*3))] > 0, short VXX. If < 0, cover VXX

def simulate_returnsV47VXX(dataframe, initial_investment, trade_cost, threshold, start_date=None):
    """
    Simulates returns from shorting VXX using existing dataset (fixed dataset based on summary dataframe)
    allows for varying the initial_investment, trade_cost, threshold, and start date (date must be in dataframe)
    Utilizes new formula [((VV-V)/VV) - ((V7-V4)/(V7*3))]
    """
    
    if start_date is not None:
        d1 = np.where(dataframe['Date'].values == start_date)[0][0]
        summary = dataframe.iloc[d1:, :].copy()
        summary.reset_index(drop = True, inplace = True)
    else:
        summary = dataframe.copy()
    
    summary.loc[0, 'Holding':] = float(0) #initialize as 0 holdings
    LTshares = (initial_investment - trade_cost) / summary.loc[0, 'SPY']
    summary.loc[0, 'Long Term Shares'] = LTshares
    summary.loc[0, 'Long Term Value'] = initial_investment - trade_cost
    summary.loc[0, 'Cash'] = initial_investment

    def update_row(df, row):
        """
        basic steps that will be repeated to update each row of summary DF
        """ 
        df.loc[row, 'Held Value'] = df.loc[row, 'Holding']*df.loc[row, 'VXX']
        df.loc[row, 'Long Term Shares'] = LTshares
        df.loc[row, 'Long Term Value'] = df.loc[row, 'Long Term Shares']*df.loc[row, 'SPY']
        df.loc[row, 'Trade Sum'] = df.loc[row, 'Cash'] + df.loc[row, 'Held Value']
        return df

    for i in range(1, summary.shape[0]):
        #print(i)
        if np.absolute(summary.loc[i, '[((VV-V)/VV) - ((V7-V4)/(V7*3))]']) <= threshold: #do nothing
            #print('do nothing')
            summary.loc[i, 'Holding'] = summary.loc[i-1, 'Holding']
            summary.loc[i, 'Cash'] = summary.loc[i-1, 'Cash']
            summary = update_row(summary, i)

        elif (summary.loc[i, '[((VV-V)/VV) - ((V7-V4)/(V7*3))]'] + threshold > 0) & (summary.loc[i-1, 'Holding'] == 0): #buy
            #print(short sell)
            summary.loc[i, 'Holding'] = (summary.loc[i-1, 'Cash'] - trade_cost) / -summary.loc[i, 'VXX']
            summary.loc[i, 'Cash'] = summary.loc[i-1, 'Cash'] - trade_cost -(summary.loc[i, 'Holding']*summary.loc[i, 'VXX'])
            summary = update_row(summary, i)

        elif (summary.loc[i, '[((VV-V)/VV) - ((V7-V4)/(V7*3))]'] - threshold < 0) & (summary.loc[i-1, 'Held Value'] != 0): #sell
            #print('sell')
            summary.loc[i, 'Cash'] = summary.loc[i-1, 'Cash'] + summary.loc[i-1, 'Held Value'] - trade_cost
            summary.loc[i, 'Holding'] = 0
            summary.loc[i, 'Held Value'] = 0
            summary = update_row(summary, i)

        else: #also do nothing
            #print('do nothing')
            summary.loc[i, 'Holding'] = summary.loc[i-1, 'Holding']
            summary.loc[i, 'Cash'] = summary.loc[i-1, 'Cash']
            summary = update_row(summary, i)
            
    return summary

# %% [markdown]
# Run simulations for multiple costs per trade and thresholds:

# %%
#Simulate buying SPY according to new formula
summary1 = simulate_returnsV47SPY(summary, 1000, 0, 0)

fig = plt.figure(figsize = (12, 12))
plt.plot(np.arange(summary1.shape[0]-1), summary1.loc[1:, 'Trade Sum'], label = 'Active Trading SPY')
plt.plot(np.arange(summary1.shape[0]-1), summary1.loc[1:, 'Long Term Value'], label = 'Buy and Hold SPY')
plt.title('Buy SPY, Cost per Trade = 0, Trade threshold = 0')
plt.legend()

# %%
#Simulate shoting VXX according to new formula
summary2 = simulate_returnsV47VXX(summary, 1000, 5, 0) #, start_date = '2017-01-20')

fig = plt.figure(figsize = (12, 12))
plt.plot(np.arange(summary2.shape[0]-1), summary2.loc[1:, 'Trade Sum'], label = 'Active Trading VXX')
plt.plot(np.arange(summary2.shape[0]-1), summary2.loc[1:, 'Long Term Value'], label = 'Buy and Hold SPY')
plt.title('Short VXX, Cost per Trade = 5, Trade threshold = 0')
plt.legend()

# %%
pd.options.display.max_rows = 5000
summary2
# Out:
# 2203    840475          12.0126         3084.22
# 2204    847802          12.0126         3089.03
# 2205    845318          12.0126         3093.11
# 2206    850037          12.0126         3094.31
# 2207    850658          12.0126         3104.65
# 2208    854632          12.0126         3109.45
# 2209    852396          12.0126         3107.29
# 2210    852272          12.0126         3112.57
# 2211    846436          12.0126         3101.28
# 2212    836501          12.0126         3100.32
# 2213    835259          12.0126          3103.2
# 2214    832030          12.0126            3096
# 2215    815266          12.0126          3080.5
# 2216    833893          12.0126         3106.69
# 2217    840847          12.0126         3097.56
# 2218    854383          12.0126         3102.84
# 2219    870031          12.0126         3123.14
# 2220    873880          12.0126         3120.38
# 2221    875743          12.0126         3127.59
# 2222    875867          12.0126         3126.03
# 2223    881083          12.0126         3157.74
# 2224    872638          12.0126         3155.82
# 2225    871645          12.0126         3183.45
# 2226    860965          12.0126         3176.84
# 2227    863946          12.0126            3173
# 2228    865684          12.0126         3161.58
# 2229    866181          12.0126         3162.19
# 2230    879220          12.0126         3172.16
# 2231    892011          12.0126         3189.45
# 2232    904926          12.0126         3199.06
# 2233    903808          12.0126         3204.71
# 2234    904802          12.0126         3204.35
# 2235    907037          12.0126         3191.26
# 2236    918586          12.0126         3201.47
# 2237    923678          12.0126         3221.77
# 2238    922436          12.0126         3209.39
# 2239    923429          12.0126         3207.71
# 2240    925913          12.0126         3214.32
# 2241    924299          12.0126         3213.48
# 2242    923678          12.0126         3209.63
# 2243    922188          12.0126          3211.2
# 2244    927528          12.0126          3217.8
# 2245    921939          12.0126         3205.67
# 2246    933985          12.0126         3228.61
# 2247    941064          12.0126         3249.04
# 2248    941809          12.0126         3262.73
# 2249    942305          12.0126         3284.47
# 2250    946031          12.0126         3290.48
# 2251    942305          12.0126         3297.93
# 2252    945907          12.0126         3292.88
# 2253    947769          12.0126         3316.91
# 2254    947645          12.0126         3338.53
# 2255    947640          12.0126         3327.12
# 2256    947635          12.0126         3358.83
# 2257    943044          12.0126         3353.18
# 2258    947988          12.0126         3368.44
# 2259    968121          12.0126         3395.83
# 2260    952580          12.0126         3403.04
# 2261    928562          12.0126         3401.72
# 2262    912668          12.0126         3403.16
# 2263    919026          12.0126         3442.56
# 2264    848033          12.0126         3419.73
# 2265    848028          12.0126         3384.66
# 2266    848028          12.0126         3386.34
# 2267    848028          12.0126          3382.5
# 2268    848028          12.0126         3308.86
# 2269    848028          12.0126         3170.47
# 2270    848028          12.0126         3232.94
# 2271    848028          12.0126          3215.4
# 2272    848028          12.0126         3094.79
# 2273    848028          12.0126         3141.28
# 2274    848028          12.0126         3187.41

# %%
short_sum = summary2.loc[1:, 'Trade Sum'].values

running_max = 0
pdrop_max = 0

for i in range(short_sum.shape[0]):
    running_max = np.maximum(running_max, short_sum[i])
    percent_drop = (running_max - short_sum[i])/running_max
    if percent_drop > pdrop_max:
        pdrop_max = percent_drop
        
print(pdrop_max)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-811aea8a50a7> in <module>()
# ----> 1 short_sum = summary2.loc[1:, 'Trade Sum'].values
#       2
#       3 running_max = 0
#       4 pdrop_max = 0
#       5
#
# NameError: name 'summary2' is not defined
